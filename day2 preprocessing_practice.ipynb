# %% [markdown]
# <a href="https://colab.research.google.com/github/AlvinMathew001/AI-ML-Internship/blob/main/day2%20preprocessing_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/preprocessing_practice_dataset.csv")

# %%
df.describe()
# Out:
#        Employee_ID        Age  Experience_Years  Monthly_Salary  \
# count   100.000000  90.000000        100.000000       90.000000
# mean   1050.500000  39.866667          9.360000    75111.988889
# std      29.011492  11.015005          6.210971    28068.924984
# min    1001.000000  21.000000          0.000000    25412.000000
# 25%    1025.750000  29.250000          4.000000    50536.250000
# 50%    1050.500000  41.000000         10.000000    72715.500000
# 75%    1075.250000  48.000000         15.000000    99079.000000
# max    1100.000000  59.000000         19.000000   119297.000000
#
#        Performance_Rating
# count          100.000000
# mean             3.230000
# std              1.476106
# min              1.000000
# 25%              2.000000
# 50%              4.000000
# 75%              5.000000
# max              5.000000

# %%
df['Age_mean_imputed']=df['Age'].fillna(df['Age'].mean())
df['Age_median_imputed']=df['Age'].fillna(df['Age'].median())
df[['Age','Age_mean_imputed','Age_median_imputed']]
# Out:
#      Age  Age_mean_imputed  Age_median_imputed
# 0   59.0              59.0                59.0
# 1   49.0              49.0                49.0
# 2   35.0              35.0                35.0
# 3   28.0              28.0                28.0
# 4   41.0              41.0                41.0
# ..   ...               ...                 ...
# 95  54.0              54.0                54.0
# 96  53.0              53.0                53.0
# 97  43.0              43.0                43.0
# 98  44.0              44.0                44.0
# 99  57.0              57.0                57.0
#
# [100 rows x 3 columns]

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')
plt.title('Boxplot of Experience Years vs Monthly Salary')
plt.xlabel('Experience Years')
plt.ylabel('Monthly Salary')
plt.show()
# Out:
# /tmp/ipykernel_15132/3253470997.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(21,6))
sns.boxplot(data=df,x='Age',y='Experience_Years',palette='pastel')
plt.title('Boxplot of Experience and Age')
plt.show()
# Out:
# /tmp/ipykernel_15132/3072157862.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Age',y='Experience_Years',palette='pastel')

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(21,6))
sns.boxplot(data=df,x='Education',y='Monthly_Salary',palette='pastel')
plt.title('Boxplot of Education and Monthly_Salary')
plt.show()
# Out:
# /tmp/ipykernel_15132/831774431.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Education',y='Monthly_Salary',palette='pastel')

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(21,6))
sns.boxplot(data=df,x='Department',y='Performance_Rating',palette='pastel')
plt.title('Boxplot of Department and Performance_Rating')
plt.show()
# Out:
# /tmp/ipykernel_15132/2723442099.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Department',y='Performance_Rating',palette='pastel')

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(21,6))
sns.boxplot(data=df,x='Gender',y='Performance_Rating',palette='pastel')
plt.title('Boxplot of Gender and Performance_Rating')
plt.show()
# Out:
# /tmp/ipykernel_15132/2665211324.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Gender',y='Performance_Rating',palette='pastel')
